# %% [markdown]
# **Name : Sonal Shukla**(CS23176)

# %% [markdown]
# **AIM :** To implement the K-means clustering algorithm and analyze the clustering results using appropriate evaluation techniques.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
path="/content/drive/MyDrive/ML_DATASETS/Mall_Customers - Mall_Customers.csv"
df=pd.read_csv(path)
df.head(5)

# %%
df.info()

# %%
df.describe()

# %%
df.shape

# %%
df.isnull().sum()

# %%
df.columns

# %%
X=df.iloc[:, [3,4]].values
print(X)

# %%
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

# %%
print(X_scaled)

# %%
inertia_values=[]
for k in range(1,11):
  kmeans=KMeans(n_clusters=k,random_state=42)
  kmeans.fit(X_scaled)
  inertia_values.append(kmeans.inertia_)
print(inertia_values)

plt.figure()
plt.plot(range(1,11),inertia_values,marker='o')
plt.xlabel("Number of Clusters(K) ")
plt.ylabel("Inertia ")
plt.title("Elbow Method for optimal K")

# %%
kmeans=KMeans(n_clusters=4,random_state=42)#assume K=5
clusters=kmeans.fit_predict(X_scaled)

df['Cluster']=clusters
print(df.head())

# %%
print(df)

# %%
print("Inertia :",kmeans.inertia_)

sil_score=silhouette_score(X_scaled,clusters)
print("Silhouette Score :",sil_score)

# %%
plt.figure()
sns.scatterplot(x='Annual Income (k$)',y='Spending Score (1-100)',hue='Cluster',data=df, palette='Set1')

centroids=scaler.inverse_transform(kmeans.cluster_centers_)
plt.scatter(centroids[:,0],centroids[:,1],s=200,c='black',marker='X',label='Centroids')
plt.title('Customer segmentation using k means')
plt.legend()
plt.show()
